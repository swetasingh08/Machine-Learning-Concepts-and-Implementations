# %%
#  Write a program to implement k-Nearest Neighbour algorithm to classify the iris data set. Print both correct and wrong predictions. Java/Python ML library classes can be used for this problem

# %%
import csv
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Class mapping
class_dict = {'setosa': 0, 'versicolor': 1, 'virginica': 2}

# Reverse mapping (for printing names)
reverse_class_dict = {v: k for k, v in class_dict.items()}

# Load dataset
with open('iris.csv') as csvFile:
    dataset = [line for line in csv.reader(csvFile)]
    dataset = dataset[1:]

    X = []
    y = []

    for line in dataset:
        X.append(line[:-1])
        y.append(class_dict[line[-1]])

# Convert to numpy
X = np.array(X).astype(float)
y = np.array(y).astype(int)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# KNN model
classifier = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2)
classifier.fit(X_train, y_train)

# Predictions
y_pred = classifier.predict(X_test)

# Accuracy
print("Accuracy: ", accuracy_score(y_test, y_pred))

# ------------------ OUTPUT ------------------

print("Correct Predictions:")
for i in range(len(y_test)):
    if y_test[i] == y_pred[i]:
        print(f"Input: {X_test[i]} | Actual: {reverse_class_dict[y_test[i]]} | Predicted: {reverse_class_dict[y_pred[i]]}")

print(" Wrong Predictions:")
for i in range(len(y_test)):
    if y_test[i] != y_pred[i]:
        print(f"Input: {X_test[i]} | Actual: {reverse_class_dict[y_test[i]]} | Predicted: {reverse_class_dict[y_pred[i]]}")
# Out:
# Accuracy:  0.9459459459459459
# Correct Predictions:
# Input: [5.  3.4 1.5 0.2] | Actual: setosa | Predicted: setosa
# Input: [5.1 3.4 1.5 0.2] | Actual: setosa | Predicted: setosa
# Input: [6.5 3.  5.5 1.8] | Actual: virginica | Predicted: virginica
# Input: [4.7 3.2 1.6 0.2] | Actual: setosa | Predicted: setosa
# Input: [5.2 3.4 1.4 0.2] | Actual: setosa | Predicted: setosa
# Input: [4.8 3.  1.4 0.3] | Actual: setosa | Predicted: setosa
# Input: [6.3 3.3 4.7 1.6] | Actual: versicolor | Predicted: versicolor
# Input: [6.1 2.6 5.6 1.4] | Actual: virginica | Predicted: virginica
# Input: [6.  2.9 4.5 1.5] | Actual: versicolor | Predicted: versicolor
# Input: [4.8 3.4 1.9 0.2] | Actual: setosa | Predicted: setosa
# Input: [6.  3.4 4.5 1.6] | Actual: versicolor | Predicted: versicolor
# Input: [6.4 2.8 5.6 2.2] | Actual: virginica | Predicted: virginica
# Input: [7.1 3.  5.9 2.1] | Actual: virginica | Predicted: virginica
# ...
