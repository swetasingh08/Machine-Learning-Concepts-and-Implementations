# %%
# For a given set of training data examples stored in a .CSV file, implement and demonstrate the Candidate-Elimination algorithm to output a description of the set of all hypotheses consistent with the training examples.

# %%
import csv
import pandas as pd
with open("trainingexamples.csv") as f:
    csv_file = csv.reader(f)
    data = list(csv_file)
df = pd.DataFrame(data[1:], columns=data[0])
df.index = [f"Row{i+1}" for i in range(len(df))]

print("Dataset:")
print(df.to_string())

specific = data[1][:-1]   
general = [['?' for i in range(len(specific))] for j in range(len(specific))]

print("\nInitial Specific Hypothesis (S0) and Initial General Hypothesis (G0):")
print(specific)
print(general)

for i in data[1:]:
    if i[-1] == "Yes":
        for j in range(len(specific)):
            if i[j] != specific[j]:
                specific[j] = "?"
                general[j][j] = "?"

    elif i[-1] == "No":
        for j in range(len(specific)):
            if i[j] != specific[j]:
                general[j][j] = specific[j]
            else:
                general[j][j] = "?"

    print("\nStep " + str(data.index(i)) + " of Candidate Elimination Algorithm")
    print("S:", specific)
    print("G:", general)

gh = []
for i in general:
    for j in i:
        if j != '?':
            gh.append(i)
            break

print("\nFinal Specific Hypothesis:\n", specific)
print("\nFinal General Hypothesis:\n", gh)
# Out:
# Dataset:
#         sky airtemp humidity    wind water forcast enjoysport
# Row1  Sunny    Warm   Normal  Strong  Warm    Same        Yes
# Row2  Sunny    Warm     High  Strong  Warm    Same        Yes
# Row3  Rainy    Cold     High  Strong  Warm  Change         No
# Row4  Sunny    Warm     High  Strong  Cool  Change        Yes
#
# Initial Specific Hypothesis (S0) and Initial General Hypothesis (G0):
# ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same']
# [['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]
#
# Step 1 of Candidate Elimination Algorithm
# S: ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same']
# G: [['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]
#
# Step 2 of Candidate Elimination Algorithm
# S: ['Sunny', 'Warm', '?', 'Strong', 'Warm', 'Same']
# G: [['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]
#
# Step 3 of Candidate Elimination Algorithm
# S: ['Sunny', 'Warm', '?', 'Strong', 'Warm', 'Same']
# G: [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', 'Same']]
#
# Step 4 of Candidate Elimination Algorithm
# S: ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# G: [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]
#
# Final Specific Hypothesis:
#  ['Sunny', 'Warm', '?', 'Strong', '?', '?']
#
# Final General Hypothesis:
#  [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
